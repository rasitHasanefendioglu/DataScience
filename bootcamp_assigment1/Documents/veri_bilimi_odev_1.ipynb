# %% [markdown]
# # Techcareer.net: Python ile Veri Bilimi Ödev 1
# ### Mevlüt Uzun

# %%
# Pandas, numpy, matplotlib ve seaborn kütüphanelerini yükleyelim - 2p

# %% [markdown]
# ### Veri seti 1: Öğrenci Notları

# %%
# StudentsPerformance.csv dosyasını açalım - 2p

# Veri setinin ilk 20 satırını yazdıralım - 2p

# Veri setinin sütun isimlerini yazdıralım - 2p

# Veri setinin satır ve sütun sayısını yazdıralım - 2p

# %%
# Giriş olarak cinsiyet değerini alan, çıkış olarak o cinsiyet grubuna ait veriyi veren bir fonksiyon yazın. - 5p
def getByGender()...

# Her bir ebeveyn eğitim seviyesine karşılık kaç öğrenci olduğunu gösteren bir fonksiyon yazın. - 5p
def countByParentEducation()...

# Test ön hazırlık dersini alıp almama durumuna göre sınav sonuçlarının ortalama, min, ve max değerlerini hesaplayın. - 5p
def getStatsByPrep()...

# %%
# Aşağıdaki tabloyu oluşturan kodu yazın. - 5p
# Out:
#                       min                                max       \
#                math score      reading score      math score
# gender             female male        female male     female male
# race/ethnicity
# group A                34   28            43   23         92  100
# group B                 8   30            24   24         97   94
# group C                 0   27            17   28         96   98
# group D                26   39            31   34         98  100
# group E                32   30            34   26        100  100
#
#                                         mean                           \
#                reading score      math score            reading score
# gender                female male     female       male        female
# race/ethnicity
# group A                  100   96  58.527778  63.735849     69.000000
# group B                   97   96  61.403846  65.930233     71.076923
# ...

# %%
# Aşağıdaki resmi oluşturan kodu yazın. - 5p

# %%
# Aşağıdaki resmi oluşturan kodu yazın. -5p

# %% [markdown]
# ### Veri seti 2: Netflix Veritabanı

# %%
# Netflix veritabanı dosyasını (netflix_titles.csv) açın
nf =

# %%
# Yalnızca dizilere ait veriyi getiren bir fonksiyon yazın. - 5p
def getShows()...

# İçerisinde not a number bulunan sütun isimlerini yazdırın. - 5p
nan_columns = ...

# Verinin içerisindeki 20 dakikadan kısa filmleri seçebilen, ve yeni bir sütunda filmlerin kısa film olup olmaıdğını belirten kodu yazın. - 10p
kisa_film_mi = ...
nf["kisa_film"] = ...

# Verilen bir sütun için not a number değerleri istenilen değerle değiştiren fonksiyon yazın. Ör: NaN ülkeleri Country diye değiştirsin. - 5p
def replaceNan(pColumn, pValue)...

# Girdisi yönetmen ismi, çıktısı o yönetmene ait film ve diziler olan bir fonksiyon yazın. Listede olmayan yönetmen isimleri için uyarı versin. - 10p
def getByDirector()...

# İsmi verilen bit oyuncunun hangi dizi/filmlerde rol aldığını listeleyen bir fonksiyon yazın. (ipucu: Python'un 'in' komutunu kullanabilirsiniz.) - 10p
def getByName()...

# %%
# Aşağıdaki resmi oluşturan kodu yazın. -5p

# %%
# Aşağıdaki resmi oluşturan kodu yazın. -5p

# %% [markdown]
# ### Veri Seti 3: Uçuş Kaydı

# %%
# Flight.csv dosyası 3.5 saatlik bir ticarı uçuşa ait verileri içermektedir.
# Bu veriyi, çalışması daha kolay yeni bir dosya haline getireceğiz.

# 1. Dosyayı pandas ile okuyun.

# 2. Veride 1219 nitelik bulunuyor.
# Sütun isimleriniz orijinal verinin 3. satırındaki (Frame-sf ile başlayan) isimler olacak.
# İpucu: read_csv kullanırken skiprows, nrows ve header parametrelerini düzenlemeniz gerekecek.

# 3. Numerik değerlerdeki NaN değerleri interpole ederek düzeltin.

# 4. Numerik olmayan, kategorik değerleri 0-1 şeklinde numerik hale çevirin. (Örnek: DOWN:0, NOTDOWN:1, UP:2 gibi)

# 5. Verinin ilk satırındaki tarih bilgisi ile üçüncü sütundaki saat-dakika bilgisini birleştirerek Datetime içeren bir sütun oluşturun.

# 6. Bazı nitelikler birden fazla sütunda bulunmaktadır. Bunun sebebi aynı parametrenin birkaç farklı kaynaktan gelmesidir.
# Bu sütunların ortalamasını alarak tek bir sütun haline getirin. 
# Örnek: AILERON_POS_L dört farklı sütunda bulunmaktadır. Bunu ortalamaları alarak tek sütuna düşürün.
# İpucu: mean fonksiyonu içerisinde axis değerini belirtmeniz gerekecek.
# İpucu: Sütun bazında data type için df["Parametre ismi"].dtype kullanabilirsiniz.

# 7. Yeni dataframe'i AX-WND_12_12_2020.csv şeklinde kaydedin.
# Not: Yukarıda belirtilen dosya ismini string olarak sizin verideki bilgiyi çekerek oluşturmanız gerekiyor.

# 8. "FUEL FLOW #1" parametresi ile en yüksek korelasyona sahip ilk 20 parametreyi içeren dataframe i yeni bir dosya olarak kaydedin.

# 9. Veriyi olabildiğince en az hafıza kaplayacak şekilde düzenleyin.

# 10. Yukarıdaki işlemleri class yapısı içinde ayrı ayrı fonksiyonlar şeklinde yapın.
